# %%
#!pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
import os
import pandas as pd 
import snscrape.modules.twitter as sntwitter
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %%
tweets=[]
keywords = ['congress punjab','captain punjab', 'captain Amarinder Singh','कांग्रेस पंजाब','कप्तान पंजाब', 'कप्तान अमरिंदर सिंह','ਕਾਂਗਰਸ ਪੰਜਾਬ','ਕੈਪਟਨ ਪੰਜਾਬ', 'ਕੈਪਟਨ ਅਮਰਿੰਦਰ ਸਿੰਘ']
queries = []
tot = len(keywords)
curr = 1
for keyword in keywords:
    queries.append(keyword + 'since:2017-02-12 until:2017-03-04')
df = pd.DataFrame()
for query in queries:
    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
        if i%500==0:
            print(tweet.date)
            print(f'{curr}/{tot}', i)
        tweets.append([tweet.url, tweet.id, tweet.date, tweet.user.location, tweet.user.username, tweet.user.displayname, tweet.user.verified, tweet.user.followersCount, tweet.user.friendsCount, tweet.lang, tweet.content, tweet.user.description, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.hashtags])
    curr+=1
    # Creating a dataframe from the tweets list above
    df = df.append(pd.DataFrame(tweets, columns=['url', 'id', 'datetime', 'location', 'username', 'displayname', 'verified', 'followerCount', 'friendsCount', 'language', 'content', 'bio', 'likes', 'retweets', 'quotes', 'comments', 'hashtags']))
# Out:
# 2017-03-03 18:32:21+00:00
# 4/9 0
# 2017-02-21 14:29:36+00:00
# 5/9 0
# 2017-03-02 09:13:15+00:00
# 7/9 0
# 2017-02-26 07:22:06+00:00
# 8/9 0
# 2017-03-03 02:17:55+00:00
# 9/9 0

# %%
df.drop_duplicates(subset=['content', 'username', 'datetime'], inplace=True)

# %%
#CONGRESS
df.shape
# Out:
# (193, 17)

# %%
df.to_csv('pb17_Congress_12feb04Mar.csv')

# %%
df.tail(10)
# Out:
#                                                                url                  id                  datetime              location         username          displayname verified followerCount friendsCount language                                                                                                                                                                 content                                                                                                                                                              bio likes retweets quotes comments  hashtags
# 188      https://twitter.com/ZeePunjabHH/status/832565709674782721  832565709674782721 2017-02-17 12:21:48+00:00   Noida Sector-16, UP      ZeePunjabHH              Zee PHH     True         44821          108       pa      ਫਤਿਹਗੜ੍ਹ ਸਾਹਿਬ 'ਚ ਹੋਈ SGPC ਦੀ ਬੈਠਕ\nਬੇਅਦਬੀ ਮਾਮਲਿਆਂ 'ਤੇ ਕੈਪਟਨ ਫਿਕਰਮੰਦ\nਬਦਲੀ ਗਈ ਪਾਣੀ ਵਾਲੀ ਬੱਸ !\nਸਵਾਲਾਂ ਦੇ ਘੇਰੇ 'ਚ ਖਾਕੀ\nਪੰਜਾਬ ਕੀ ਬਾਤ, 6 ਵਜੇ https://t.co/cMzAdiENp7                                                            पंजाब, हरियाणा, हिमाचल और जम्मू-कश्मीर की ख़बरों के लिए बने रहिए हमारे साथ... Follow Us- @ZeePunjabHH     3        0      0        0      None
