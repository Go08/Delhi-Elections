# %%
#!pip install googletrans==4.0.0-rc1
from googletrans import Translator
import pandas as pd
import googletrans
from googletrans import Translator
import time

# %%
df=pd.read_csv("E:\Capstone\Scraper\pb17_Akali_12feb04Mar.csv", low_memory=False, lineterminator='\n')

# %%
df.head(1)
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://twitter.com/BorntoShineee/status/14951...
#
#                     id                   datetime location       username  \
# 0  1495184723659792387  2022-02-19 23:53:11+00:00   Canada  BorntoShineee
#
#                  displayname  verified  followerCount  friendsCount language  \
# 0  Mr. Singh Deol 🌾🌾🧑‍🌾🇮🇳🇨🇦🙏     False           3037          1673       en
#
#                                              content  \
# 0  Vote wisely Punjab,\nLet’s change the regime o...
#
#                                                  bio  likes  retweets  quotes  \
# 0  Support Farmer🙏🙏👍/ #NoFarmerNoFood #FarmersPro...      4         2       1
#
#    comments                 hashtags\r
# 0         0  ['PunjabElections2022']\r

# %%
df.shape
# Out:
# (5347, 18)

# %%
error_indices = []

# %%
translator = Translator()

def trans(ele):
    try:
        #time.sleep(0.5)
        print(df.index[df['content'] == ele][0])
        return(translator.translate(ele).text)
    except Exception as e:
        print(e)
        error_indices.append(df.index[df['content'] == ele][0])
        return ele

# %%
df['content_re'] = df['content'].apply(lambda ele: trans(ele))
# Out:
# 0
# 'Translator' object has no attribute 'raise_Exception'
# 1
# 'Translator' object has no attribute 'raise_Exception'
# 2
# 'Translator' object has no attribute 'raise_Exception'
# 3
# 'Translator' object has no attribute 'raise_Exception'
# 4
# 'Translator' object has no attribute 'raise_Exception'
# 5
# 'Translator' object has no attribute 'raise_Exception'
# 6
# 'Translator' object has no attribute 'raise_Exception'
# 7
# 'Translator' object has no attribute 'raise_Exception'
# 8
# 'Translator' object has no attribute 'raise_Exception'
# 9
# 'Translator' object has no attribute 'raise_Exception'
# 10
# 'Translator' object has no attribute 'raise_Exception'
# 11
# 'Translator' object has no attribute 'raise_Exception'
# 12
# 'Translator' object has no attribute 'raise_Exception'
# 13
# 'Translator' object has no attribute 'raise_Exception'
# 14
# 'Translator' object has no attribute 'raise_Exception'
# 15
# 'Translator' object has no attribute 'raise_Exception'
# 16
# ...

# %%
errors_df = pd.DataFrame(error_indices)
errors_df.to_csv('pb22_Akali_1feb20feb_trans_sampled_errors.csv', index=False)

# %%
#df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-93f383890bb8> in <module>
# ----> 1 df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.to_csv('pb22_Akali_1feb20feb_trans_sampled.csv')

# %%
new_df = pd.read_csv('pb22_Akali_1feb20feb_trans_sampled.csv', low_memory=False, lineterminator='\n')

# %%
new_df.tail(3)
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 5375        5375          5379
# 5376        5376          5380
# 5377        5377          5381
#
#                                                     url                   id  \
# 5375  https://twitter.com/Vikram67694664/status/1489...  1489822597055651841
# 5376  https://twitter.com/TigerJa28019266/status/148...  1488773676703100934
# 5377  https://twitter.com/JoraSinghs/status/14884407...  1488440733543858180
#
#                        datetime location         username displayname  \
# 5375  2022-02-05 04:46:01+00:00      NaN   Vikram67694664      Vikram
# 5376  2022-02-02 07:17:59+00:00      NaN  TigerJa28019266   jora jatt
# 5377  2022-02-01 09:14:59+00:00      NaN       JoraSinghs   ਜੋਰਾ ਸਿੰਘ
#
#       verified  followerCount  friendsCount language  \
# 5375     False              0            17       pa
# 5376     False              4             3       pa
# 5377     False             55            49       pa
#
# ...
